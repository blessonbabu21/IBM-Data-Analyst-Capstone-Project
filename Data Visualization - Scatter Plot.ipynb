# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Scatter Plot**

# %% [markdown]
# Estimated time needed: **45** minutes

# %% [markdown]
# ## Overview
#
# In this lab, you will focus on creating and interpreting scatter plots to visualize relationships between variables and trends in the dataset. The provided dataset will be directly loaded into a pandas DataFrame, and various scatter plot-related visualizations will be created to explore developer trends, compensation, and preferences.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will:
#
# - Create and analyze scatter plots to examine relationships between variables.
#
# - Use scatter plots to identify trends and patterns in the dataset.
#
# - Focus on visualizations centered on scatter plots for better data-driven insights.

# %% [markdown]
# ## Setup: Working with the Database

# %% [markdown]
# **Install and import the required libraries**

# %%
# !pip install pandas
# !pip install matplotlib

import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Step 1: Load the dataset

# %%
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv"

df = pd.read_csv(file_path)

# %% [markdown]
# ### Task 1: Exploring Relationships with Scatter Plots

# %% [markdown]
# #### 1. Scatter Plot for Age vs. Job Satisfaction

# %% [markdown]
# Visualize the relationship between respondents' age (`Age`) and job satisfaction (`JobSatPoints_6`). Use this plot to identify any patterns or trends.

# %%
## Write your code here
import seaborn as sns
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='Age', y='JobSatPoints_6', alpha=0.5)
plt.title("Age vs Job Satisfaction")
plt.xlabel("Age")
plt.ylabel("Job Satisfaction Score (1–5)")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 2. Scatter Plot for Compensation vs. Job Satisfaction

# %% [markdown]
# Explore the relationship between yearly compensation (`ConvertedCompYearly`) and job satisfaction (`JobSatPoints_6`) using a scatter plot.

# %%
## Write your code here
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='ConvertedCompYearly', y='JobSatPoints_6', alpha=0.5)
plt.title("Yearly Compensation vs Job Satisfaction")
plt.xlabel("Yearly Compensation")
plt.ylabel("Job Satisfaction Score")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 2: Enhancing Scatter Plots

# %% [markdown]
# #### 1. Scatter Plot with Trend Line for Age vs. Job Satisfaction

# %% [markdown]
# Add a regression line to the scatter plot of Age vs. JobSatPoints_6 to highlight trends in the data.

# %%
## Write your code here
plt.figure(figsize=(8, 5))
sns.regplot(data=df, x='Age', y='JobSatPoints_6', scatter_kws={'alpha':0.3})
plt.title("Age vs Job Satisfaction with Trend Line")
plt.xlabel("Age")
plt.ylabel("Job Satisfaction Score")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# DTypePromotionError                       Traceback (most recent call last)
# Cell In[9], line 3
#       1 ## Write your code here
#       2 plt.figure(figsize=(8, 5))
# ----> 3 sns.regplot(data=df, x='Age', y='JobSatPoints_6', scatter_kws={'alpha':0.3})
#       4 plt.title("Age vs Job Satisfaction with Trend Line")
#       5 plt.xlabel("Age")
#
# File /opt/conda/lib/python3.12/site-packages/seaborn/regression.py:775, in regplot(data, x, y, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     773 scatter_kws["marker"] = marker
#     774 line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 775 plotter.plot(ax, scatter_kws, line_kws)
#     776 return ax
#
# ...

# %% [markdown]
# #### 2. Scatter Plot for Age vs. Work Experience

# %% [markdown]
# Visualize the relationship between Age (`Age`) and Work Experience (`YearsCodePro`) using a scatter plot.

# %%
## Write your code here
# Clean 'YearsCodePro'
df['YearsCodePro'] = df['YearsCodePro'].replace({
    'Less than 1 year': 0,
    'More than 50 years': 51
})
df['YearsCodePro'] = pd.to_numeric(df['YearsCodePro'], errors='coerce')

plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='Age', y='YearsCodePro', alpha=0.5)
plt.title("Age vs Work Experience")
plt.xlabel("Age")
plt.ylabel("Years of Professional Coding")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 3: Combining Scatter Plots with Additional Features

# %% [markdown]
# #### 1. Bubble Plot of Compensation vs. Job Satisfaction with Age as Bubble Size

# %% [markdown]
# Create a bubble plot to explore the relationship between yearly compensation (`ConvertedCompYearly`) and job satisfaction (`JobSatPoints_6`), with bubble size representing age.

# %%
## Write your code here
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='ConvertedCompYearly', y='JobSatPoints_6', size='Age', sizes=(20, 200), alpha=0.4)
plt.title("Compensation vs Job Satisfaction (Bubble Size = Age)")
plt.xlabel("Yearly Compensation")
plt.ylabel("Job Satisfaction Score")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 2. Scatter Plot for Popular Programming Languages by Job Satisfaction

# %% [markdown]
# Visualize the popularity of programming languages (`LanguageHaveWorkedWith`) against job satisfaction using a scatter plot. Use points to represent satisfaction levels for each language.

# %%
## Write your code here
# Create exploded dataframe for each language
df_lang = df[['LanguageHaveWorkedWith', 'JobSatPoints_6']].dropna()
df_lang = df_lang.assign(Language=df_lang['LanguageHaveWorkedWith'].str.split(';')).explode('Language')

# Average satisfaction by language
lang_avg = df_lang.groupby('Language')['JobSatPoints_6'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.scatterplot(data=lang_avg, x='JobSatPoints_6', y='Language')
plt.title("Average Job Satisfaction by Programming Language")
plt.xlabel("Average Job Satisfaction")
plt.ylabel("Programming Language")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 4: Scatter Plot Comparisons Across Groups

# %% [markdown]
# #### 1. Scatter Plot for Compensation vs. Job Satisfaction by Employment Type

# %% [markdown]
# Visualize the relationship between yearly compensation (`ConvertedCompYearly`) and job satisfaction (`JobSatPoints_6`), categorized by employment type (`Employment`). Use color coding or markers to differentiate between employment types.

# %%
## Write your code here
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='ConvertedCompYearly', y='JobSatPoints_6', hue='Employment', alpha=0.5)
plt.title("Compensation vs Job Satisfaction by Employment Type")
plt.xlabel("Yearly Compensation")
plt.ylabel("Job Satisfaction Score")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_970/1335225069.py:8: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %% [markdown]
# #### 2. Scatter Plot for Work Experience vs. Age Group by Country

# %% [markdown]
# Compare work experience (`YearsCodePro`) across different age groups (`Age`) and countries (`Country`). Use colors to represent different countries and markers for age groups.

# %%
## Write your code here
import matplotlib.pyplot as plt
import seaborn as sns

# Make sure Age is numeric and AgeGroup exists (from previous fix)
df['Age'] = pd.to_numeric(df['Age'], errors='coerce')
df = df.dropna(subset=['Age'])

df['AgeGroup'] = pd.cut(df['Age'], 
                        bins=[18, 25, 35, 45, 55, 65, 75, 100],
                        labels=['18–24', '25–34', '35–44', '45–54', '55–64', '65–74', '75+'])

# Define markers for each AgeGroup category
markers = ['o', 's', 'D', '^', 'v', 'P', '*']  # circle, square, diamond, triangle_up, triangle_down, plus, star
age_groups = df['AgeGroup'].cat.categories

plt.figure(figsize=(12, 8))

# Plot for each AgeGroup with a different marker
for marker, age_group in zip(markers, age_groups):
    subset = df[df['AgeGroup'] == age_group]
    sns.scatterplot(data=subset, 
                    x='AgeGroup', 
                    y='YearsCodePro', 
                    hue='Country', 
                    style='AgeGroup',  # for legend and consistent markers
                    markers=[marker], 
                    s=100,              # size of markers
                    alpha=0.7,
                    legend='full')

plt.title("Work Experience vs. Age Group by Country")
plt.xlabel("Age Group")
plt.ylabel("Years of Professional Coding")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', title='Country / AgeGroup')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_970/4076004047.py:35: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', title='Country / AgeGroup')

# %% [markdown]
# ### Final Step: Review

# %% [markdown]
# With these scatter plots, you will have analyzed data relationships across multiple dimensions, including compensation, job satisfaction, employment types, and demographics, to uncover meaningful trends in the developer community.

# %% [markdown]
# ### Summary

# %% [markdown]
# After completing this lab, you will be able to:
# - Analyze how numerical variables relate across specific groups, such as employment types and countries.
# - Use scatter plots effectively to represent multiple variables with color, size, and markers.
# - Gain insights into compensation, satisfaction, and demographic trends using advanced scatter plot techniques.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# <!--## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-10-07|1.2|Madhusudan Moole|Reviewed and updated lab|
# |2024-10-06|1.0|Raghul Ramesh|Created lab|-->

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
